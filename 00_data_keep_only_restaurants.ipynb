# %%
import json
import pymongo
import pandas as pd
myclient = pymongo.MongoClient()

# %%
df_review = pd.read_json('Data\yelp_academic_dataset_review_1000.json', lines= True)
df_review.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  VfBHSwC5Vz_pbFluy07i9Q  cjpdDjZyprfyDG3RlkVG3w  uYHaNptLzDLoV_JZ_MuzUA
# 1  3zRpneRKDsOPq92tq7ybAA  bjTcT8Ty4cJZhEOEo01FGA  uYHaNptLzDLoV_JZ_MuzUA
# 2  ne5WhI1jUFOcRn-b-gAzHA  AXgRULmWcME7J6Ix3I--ww  uYHaNptLzDLoV_JZ_MuzUA
# 3  llmdwOgDReucVoWEry61Lw  oU2SSOmsp_A8JYI7Z2JJ5w  uYHaNptLzDLoV_JZ_MuzUA
# 4  DuffS87NaSMDmIfluvT83g  0xtbPEna2Kei11vsU-U2Mw  uYHaNptLzDLoV_JZ_MuzUA
#
#    stars       date                                               text  \
# 0      5 2016-07-12  My girlfriend and I stayed here for 3 nights a...
# 1      3 2016-10-02  If you need an inexpensive place to stay for a...
# 2      3 2015-09-17  Mittlerweile gibt es in Edinburgh zwei Ableger...
# 3      4 2016-08-21  Location is everything and this hotel has it! ...
# 4      5 2013-11-20  gute lage im stadtzentrum. shoppingmeile und s...
#
#    useful  funny  cool
# 0       0      0     0
# 1       0      0     0
# ...

# %%
df_business = pd.read_json('Data\yelp_academic_dataset_business.json', lines= True)
df_business.head()
# Out:
#               business_id                             name  \
# 0  1SWheh84yJXfytovILXOAQ       Arizona Biltmore Golf Club
# 1  QXAEGFB4oINsVuTFxEYKFQ       Emerald Chinese Restaurant
# 2  gnKjwL_1w79qoiV3IC_xQQ      Musashi Japanese Restaurant
# 3  xvX2CttrVhyG2z1dFg_0xw  Farmers Insurance - Paul Lorenz
# 4  HhyxOkGAM07SRYtlQ4wMFQ              Queen City Plumbing
#
#                           address         city state postal_code   latitude  \
# 0     2818 E Camino Acequia Drive      Phoenix    AZ       85016  33.522143
# 1            30 Eglinton Avenue W  Mississauga    ON     L5R 3E7  43.605499
# 2       10110 Johnston Rd, Ste 15    Charlotte    NC       28210  35.092564
# 3   15655 W Roosevelt St, Ste 237     Goodyear    AZ       85338  33.455613
# 4  4209 Stuart Andrew Blvd, Ste F    Charlotte    NC       28217  35.190012
#
#     longitude  stars  review_count  is_open  \
# 0 -112.018481    3.0             5        0
# 1  -79.652289    2.5           128        1
# ...

# %%
#df_selected = df_review.set_index('business_id').join(df_business.set_index('business_id'), lsuffix='_review', rsuffix="_business")
df_selected = pd.merge(df_review, df_business, how="left", on='business_id', suffixes=('', '_2'))
df_selected.shape
# Out:
# (1000, 22)

# %%
df_selected.columns
# Out:
# Index(['review_id', 'user_id', 'business_id', 'stars', 'date', 'text',
#        'useful', 'funny', 'cool', 'name', 'address', 'city', 'state',
#        'postal_code', 'latitude', 'longitude', 'stars_2', 'review_count',
#        'is_open', 'attributes', 'categories', 'hours'],
#       dtype='object')

# %%
df1= df_selected
df1.shape
# Out:
# (1000, 22)

# %%
df1[df1['categories'].str.contains("Restaurant", na= False)]
# Out:
#                   review_id                 user_id             business_id  \
# 16   ByRzJ8rF2KJWLr-cUNU6EA  kzyLOqiJvyw_FWFTw2rjiQ  jQsNFOzDpxPmOurSWCg1vQ
# 17   i5UwUPlQFPLcE8p2gPFwBw  WZXp9-V2dqRRJqhGgRqueA  jQsNFOzDpxPmOurSWCg1vQ
# 18   EyQyvTTg2jX4or9bB8PC9g  XylT12exfdLiI_3uDLVIpw  jQsNFOzDpxPmOurSWCg1vQ
# 19   G-EFA005besj5uHsH0sQFA  Ji9PeffxjwqPLO7pEfSpKQ  jQsNFOzDpxPmOurSWCg1vQ
# 20   6PcJSGUBSLjt4VLXos5C4A  TLIWzAJPrET0zX4_vgvLhg  jQsNFOzDpxPmOurSWCg1vQ
# ..                      ...                     ...                     ...
# 982  NdjK8rttbevfoDwgXcL-eg  y6IogOYLjAs8Mksx62vnDQ  Jdqg97lLo_qJlCqU9RjIEA
# 983  2PoRWtHb6ulqr8AJv_QGhA  VKwI11qTXOxHmlh2yr_2TQ  Jdqg97lLo_qJlCqU9RjIEA
# 984  WlqmIvizN8A_oKNR-MPuPw  sxb4v27_35Lp1yktej7ZEQ  Jdqg97lLo_qJlCqU9RjIEA
# 998  FsS5TUFPI8QJEE60-HR3dw  bWh4k_cCuVt5GLVd33xIxg  tulUhFYMvBkYHsjmn30A9w
# 999  7xGHiLP1vAaGmX6srC_XXw  nQ4e81UdfczimYcIUtO3HA  tulUhFYMvBkYHsjmn30A9w
#
# ...

# %%
df1 = df1.set_index('review_id')

# %%
df1.columns
df1 = df1.drop(['name', 'address', 'city','state', 'postal_code','latitude', 'longitude', 'stars_2', 'review_count', 'is_open', 'attributes', 'categories', 'hours'], axis=1)

# %%
df1.to_json('Data\yelp_academic_dataset_review_1000_restaurant.json')

# %%
df1.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  VfBHSwC5Vz_pbFluy07i9Q  cjpdDjZyprfyDG3RlkVG3w  uYHaNptLzDLoV_JZ_MuzUA
# 1  3zRpneRKDsOPq92tq7ybAA  bjTcT8Ty4cJZhEOEo01FGA  uYHaNptLzDLoV_JZ_MuzUA
# 2  ne5WhI1jUFOcRn-b-gAzHA  AXgRULmWcME7J6Ix3I--ww  uYHaNptLzDLoV_JZ_MuzUA
# 3  llmdwOgDReucVoWEry61Lw  oU2SSOmsp_A8JYI7Z2JJ5w  uYHaNptLzDLoV_JZ_MuzUA
# 4  DuffS87NaSMDmIfluvT83g  0xtbPEna2Kei11vsU-U2Mw  uYHaNptLzDLoV_JZ_MuzUA
#
#    stars       date                                               text  \
# 0      5 2016-07-12  My girlfriend and I stayed here for 3 nights a...
# 1      3 2016-10-02  If you need an inexpensive place to stay for a...
# 2      3 2015-09-17  Mittlerweile gibt es in Edinburgh zwei Ableger...
# 3      4 2016-08-21  Location is everything and this hotel has it! ...
# 4      5 2013-11-20  gute lage im stadtzentrum. shoppingmeile und s...
#
#    useful  funny  cool
# 0       0      0     0
# 1       0      0     0
# ...
